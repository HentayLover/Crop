# %%
import cv2
import os

def increase_resolution(image_path, output_path, scale_factor=2):
    """
    Увеличивает разрешение изображения с помощью билинейной интерполяции.

    Args:
        image_path: Путь к исходному изображению.
        output_path: Путь к папке для сохранения обработанных изображений.
        scale_factor: Коэффициент масштабирования (2 означает увеличение в два раза).
    """
    image = cv2.imread(image_path)
    if image is not None:
        width = int(image.shape[1] *scale_factor)
        height = int(image.shape[0] *scale_factor)
        resized_image = cv2.resize(image, (width, height), interpolation=cv2.INTER_LINEAR)
        # Формируем имя файла для сохранения
        filename = os.path.basename(image_path)
        output_filename = os.path.join(output_path, filename)
        cv2.imwrite(output_filename, resized_image)
        print(f"Обработано: {filename}")
    else:
        print(f"Ошибка при загрузке: {image_path}")


if __name__ == '__main__':
    input_folder = 'images'  # Путь к папке с изображениями
    output_folder = 'resized_images'  # Путь к папке для сохранения обработанных изображений
    scale_factor = 0.5  # Коэффициент масштабирования

    os.makedirs(output_folder, exist_ok=True)  # Создаем папку для вывода, если она не существует

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(input_folder, filename)
            increase_resolution(image_path, output_folder, scale_factor)
# Out:
# Обработано: 1asf.jpg
# Обработано: 1janfdsa.jpg
# Обработано: 1_1.jpg
# Обработано: 1_transform.jpg
# Обработано: 2.jpg
# Обработано: 2a9b2319b031a694f2454d9ab61800a5-2.jpg
# Обработано: 2_1.jpg
# Обработано: 2_transform.jpg
# Обработано: 3.jpg
# Обработано: 3_1.jpg
# Обработано: 3_transform.jpg
# Обработано: 4_1.jpg

# %% [markdown]
# # Уменьшает разрешение картинки и создаёт новые файлы разметки

# %%
import cv2
import os

def increase_resolution(image_path, output_path, scale_factor=2):
    """
    Увеличивает разрешение изображения с помощью билинейной интерполяции.

    Args:
        image_path: Путь к исходному изображению.
        output_path: Путь к папке для сохранения обработанных изображений.
        scale_factor: Коэффициент масштабирования (2 означает увеличение в два раза).
    """
    image = cv2.imread(image_path)
    if image is not None:
        width = int(image.shape[1] *scale_factor)
        height = int(image.shape[0] *scale_factor)
        resized_image = cv2.resize(image, (width, height), interpolation=cv2.INTER_LINEAR)
        # Формируем новое имя файла с суффиксом "_small"
        filename = os.path.splitext(os.path.basename(image_path))[0]  # Извлекаем имя без расширения
        new_filename = filename + '_small' + os.path.splitext(os.path.basename(image_path))[1]  # Добавляем суффикс и расширение
        output_filename = os.path.join(output_path, new_filename)
        cv2.imwrite(output_filename, resized_image)
        print(f"Обработано: {new_filename}")
    else:
        print(f"Ошибка при загрузке: {image_path}")


if __name__ == '__main__':  # Исправлено: 'name' -> '__name__'
    input_folder = 'data_yolo_29_07_v1/images/train'  # Путь к папке с изображениями
    output_folder = 'new_img_small'  # Путь к папке для сохранения обработанных изображений
    scale_factor = 0.5  # Коэффициент масштабирования

    os.makedirs(output_folder, exist_ok=True)  # Создаем папку для вывода, если она не существует

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(input_folder, filename)
            increase_resolution(image_path, output_folder, scale_factor)
import os
import shutil

def copy_and_rename_txt(labels_folder, output_folder):
    """
    Копирует файлы .txt из папки labels, добавляя суффикс "_small" к их именам.

    Args:
        labels_folder: Путь к папке с файлами .txt.
        output_folder: Путь к папке для сохранения скопированных файлов.
    """
    os.makedirs(output_folder, exist_ok=True)  # Создаем папку для вывода, если она не существует

    for filename in os.listdir(labels_folder):
        if filename.lower().endswith('.txt'):
            source_path = os.path.join(labels_folder, filename)
            # Изменяем имя файла, добавляя суффикс "_small"
            new_filename = filename.replace('.txt', '_small.txt')
            target_path = os.path.join(output_folder, new_filename)
            shutil.copy2(source_path, target_path)
            print(f"Скопировано: {filename} -> {new_filename}")


if __name__ == '__main__':
    labels_folder = 'data_yolo_29_07_v1/labels/train'  # Путь к папке с файлами .txt
    output_folder = 'new_lab_small'  # Путь к папке для сохранения скопированных файлов

    copy_and_rename_txt(labels_folder, output_folder)
# Out:
# Обработано: -Pi-_QdI2K4_small.jpg
# Обработано: -Pi-_QdI2K4_transform_small.jpg
# Обработано: 00210159901_small.jpg
# Обработано: 00210159901_transform_small.jpg
# Обработано: 02490003402_small.jpg
# Обработано: 02490003402_transform_small.jpg
# Обработано: 03300012201_small.jpg
# Обработано: 03300012201_transform_small.jpg
# Обработано: 06870003202_small.jpg
# Обработано: 06870003202_transform_small.jpg
# Обработано: 06950130401_small.jpg
# Обработано: 06950130401_transform_small.jpg
# Обработано: 07_small.jpg
# Обработано: 08-02-2019-8-07-40_small.jpg
# Обработано: 08760037301_small.jpg
# Обработано: 08760037301_transform_small.jpg
# Обработано: 09520037801_small.jpg
# Обработано: 09520037801_transform_small.jpg
# Обработано: 0DACD1CF-751B-4522-A36E-8F581D411ED4-scaled_small.jpg
# Обработано: 0E3OHKAgr7U_small.jpg
# Обработано: 1_small.jpg
# Обработано: 10_small.jpg
# Обработано: 1006569_full.jpeg_small.jpg
# Обработано: 1006569_full.jpeg_transform_small.jpg
# Обработано: 10253141746_4a46b8c6bb_small.jpg
# Обработано: 1044_small.jpg
# Обработано: 1044_transform_small.jpg
# Обработано: 1076410-ptitsa-svobody-risunok-67_small.jpg
# Обработано: 1076410-ptitsa-svobody-risunok-67_transform_small.jpg
# Обработано: 1077891660.5cdd2e78ec836e9d88b47f367fc5b723_small.jpg
# Обработано: 1077891660.5cdd2e78ec836e9d88b47f367fc5b723_transform_small.jpg
# Обработано: 10_transform_small.jpg
# Обработано: 11_small.jpg
# Обработано: 1112854176.b79548629872fd2a237f5b71f297ccfc_small.jpg
# Обработано: 1112854176.b79548629872fd2a237f5b71f297ccfc_transform_small.jpg
# Обработано: 1124235234_0_87_3220_1898_1920x0_80_0_0_6a3d22d5a5692307b21d50add7931f3e_small.jpg
# Обработано: 1124235234_0_87_3220_1898_1920x0_80_0_0_6a3d22d5a5692307b21d50add7931f3e_transform_small.jpg
# Обработано: 11939229t1hf7d6_small.jpg
# Обработано: 11_transform_small.jpg
# Обработано: 12_small.jpg
# Обработано: 1200x600_0x108_wide_crop_20201021170947_d6c1e95f_b561f36e4190470e3317a4f8e7e17a4fca14dbe571da2eb150d01a27d4258311_small.jpg
# Обработано: 123_small.jpg
# Обработано: 12312415_small.jpg
# Обработано: 1234_small.jpg
# Обработано: 76_small.jpg
# Обработано: 76_transform_small.jpg
# Обработано: 77_small.jpg
# Обработано: 77_transform_small.jpg
# Обработано: 7800700250_e07d5ab7e0_b_small.jpg
# Обработано: 7871820018_d1d51a3946_small.jpg
# Обработано: 7f02b39d408d25536f77023ef10e29c5_small.jpg
# Обработано: 7_transform_small.jpg
# Обработано: 8-lytdGqbyo_small.jpg
# Обработано: 8-lytdGqbyo_transform_small.jpg
# Обработано: 8_small.jpg
# Обработано: 800x400_small.jpg
# Обработано: 800x400_transform_small.jpg
# Обработано: 815339_Prakticheskie_zanyatiya_po_upravleniyu_bespilotnimi_letatelynimi_apparatami_BPLA_Chelyabinsk_nebo_kvadrokopter_bpla_bespilotnik_dron_250x0_2382.1592.0.0_small.jpg
# Обработано: 815339_Prakticheskie_zanyatiya_po_upravleniyu_bespilotnimi_letatelynimi_apparatami_BPLA_Chelyabinsk_nebo_kvadrokopter_bpla_bespilotnik_dron_250x0_2382.1592.0.0_transform_small.jpg
# Обработано: 82f73a4617114185d2a4fd7c16f1ac19_cropped_666x443_small.jpg
# Обработано: 82f73a4617114185d2a4fd7c16f1ac19_cropped_666x443_transform_small.jpg
# Обработано: 844d1a8a60a0b3ad3b424d46e03ef1bf_small.jpg
# Обработано: 844d1a8a60a0b3ad3b424d46e03ef1bf_transform_small.jpg
# Обработано: 858x540_small.jpg
# Обработано: 8e7b95947322bcaf47299e69984d0220_small.jpg
# Обработано: 8_transform_small.jpg
# Обработано: 9_small.jpg
# Обработано: 9699e0f24e80d7ff68053bef59156cb6_small.jpg
# Обработано: 977_small.jpg
# Обработано: 999_I5NA0Rz_YlQ-598x353 (1)_small.jpg
# Обработано: 999_I5NA0Rz_YlQ-598x353 (1)_transform_small.jpg
# Обработано: 999_I5NA0Rz_YlQ-598x353_small.jpg
# Обработано: 999_I5NA0Rz_YlQ-598x353_transform_small.jpg
# Обработано: 9b3a5b54ef2284b60dceef0d2ac6a8dc0c59f473_1280_720_c_small.jpg
# Обработано: 9fa6167de0a3bdc0ba38761e40aa09dd_small.jpg
# Обработано: 9fa6167de0a3bdc0ba38761e40aa09dd_transform_small.jpg
# Обработано: 9fe9fc06d3c651c9e64637caf79104da_small.jpg
# Обработано: 9_transform_small.jpg
# Обработано: a05c597f0fd5beafc6fa40acefae0330_XL_small.jpg
# Обработано: a45e0834614f9a857abfec647e1efa61_small.jpg
# Обработано: a45e0834614f9a857abfec647e1efa61_transform_small.jpg
# Обработано: A7VEvj15109903183682_b_small.jpg
# Обработано: a97e1e7c266a741b563aae1cac24bf22_small.jpg
# Обработано: a97e1e7c266a741b563aae1cac24bf22_transform_small.jpg
# Обработано: adsfzxhfg_small.jpg
# Обработано: adsgfgjddg_small.jpg
# Обработано: aerial-view-of-landscape-against-cloudy-sky_1048944-5257_small.jpg
# Обработано: aerial-view-of-landscape-against-cloudy-sky_1048944-5257_transform_small.jpg
# Обработано: afgmdc_small.jpg
# Обработано: agricultural-drone-fly-fertilizers-pesticides-modern-agriculture-new-agricultural-innovation-automatic-drone_24901-3039_small.jpg
# Обработано: bird (4)_18720_transform_small.jpg
# Обработано: bird (4)_19240_small.jpg
# Обработано: bird (4)_19240_transform_small.jpg
# Обработано: bird (4)_19760_small.jpg
# Обработано: bird (4)_19760_transform_small.jpg
# Обработано: bird (4)_20280_small.jpg
# Обработано: bird (4)_20280_transform_small.jpg
# Обработано: bird (4)_2080_small.jpg
# Обработано: bird (4)_20800_small.jpg
# Обработано: bird (4)_20800_transform_small.jpg
# Обработано: bird (4)_2080_transform_small.jpg
# Обработано: bird (4)_21320_small.jpg
# Обработано: bird (4)_21320_transform_small.jpg
# Обработано: bird (4)_21840_small.jpg
# Обработано: bird (4)_21840_transform_small.jpg
# Обработано: bird (4)_22360_small.jpg
# Обработано: bird (4)_22360_transform_small.jpg
# Обработано: bird (4)_22880_small.jpg
# Обработано: bird (4)_22880_transform_small.jpg
# Обработано: bird (4)_23400_small.jpg
# Обработано: bird (4)_23400_transform_small.jpg
# Обработано: bird (4)_23920_small.jpg
# Обработано: bird (4)_23920_transform_small.jpg
# Обработано: bird (4)_24440_small.jpg
# Обработано: bird (4)_24440_transform_small.jpg
# Обработано: bird (4)_24960_small.jpg
# Обработано: bird (4)_24960_transform_small.jpg
# Обработано: bird (4)_25480_small.jpg
# Обработано: bird (4)_25480_transform_small.jpg
# Обработано: bird (4)_2600_small.jpg
# Обработано: bird (4)_26000_small.jpg
# Обработано: bird (4)_26000_transform_small.jpg
# Обработано: bird (4)_2600_transform_small.jpg
# Обработано: bird (4)_26520_small.jpg
# Обработано: bird (4)_26520_transform_small.jpg
# Обработано: bird (4)_27040_small.jpg
# Обработано: bird (4)_27040_transform_small.jpg
# ...
# Скопировано: maxresdefault (5).txt -> maxresdefault (5)_small.txt
# Скопировано: maxresdefault (5)_transform.txt -> maxresdefault (5)_transform_small.txt
# Скопировано: maxresdefault.txt -> maxresdefault_small.txt
# Скопировано: maxresdefault_1.txt -> maxresdefault_1_small.txt
# Скопировано: maxresdefault_transform.txt -> maxresdefault_transform_small.txt
# Скопировано: middle-20230831132011-2.txt -> middle-20230831132011-2_small.txt
# Скопировано: middle-20230831132011-2_transform.txt -> middle-20230831132011-2_transform_small.txt
# Скопировано: modern-drone-flies-forest-dark-drone-air-against-sky-white_478515-9255.txt -> modern-drone-flies-forest-dark-drone-air-against-sky-white_478515-9255_small.txt
# Скопировано: modern-drone-flies-forest-dark-drone-air-against-sky-white_478515-9255_transform.txt -> modern-drone-flies-forest-dark-drone-air-against-sky-white_478515-9255_transform_small.txt
# Скопировано: mongolfer-aerostat.txt -> mongolfer-aerostat_small.txt
# Скопировано: mountain-snow-cloud-sky-morning-mountain-range-flying-airplane-aircraft-vehicle-flight-weather-helicopter-atmospheric-phenomenon-atmosphere-of-earth-rescue-equipment-1241648.txt -> mountain-snow-cloud-sky-morning-mountain-range-flying-airplane-aircraft-vehicle-flight-weather-helicopter-atmospheric-phenomenon-atmosphere-of-earth-rescue-equipment-1241648_small.txt
# Скопировано: mqdefault.txt -> mqdefault_small.txt
# Скопировано: nature-bird-wing-cloud-sky-air-animal-seabird-fly-seagull-gull-flight-blue-blue-sky-atmosphere-of-earth-1216198.txt -> nature-bird-wing-cloud-sky-air-animal-seabird-fly-seagull-gull-flight-blue-blue-sky-atmosphere-of-earth-1216198_small.txt
# Скопировано: nature-bird-wing-cloud-sky-air-animal-seabird-fly-seagull-gull-flight-blue-blue-sky-atmosphere-of-earth-1216198_transform.txt -> nature-bird-wing-cloud-sky-air-animal-seabird-fly-seagull-gull-flight-blue-blue-sky-atmosphere-of-earth-1216198_transform_small.txt
# Скопировано: nBkSUhL2hFglnci2J76BrNOp2Z318Ji-mifGnuWR9mOBdDebBizCnTY8qdJf6ReJ58vU9meMMok3Ee2nhSR6ISeO9G1N_wjJ=U4-IrZGdE-mL2IWSe2zvvQ.txt -> nBkSUhL2hFglnci2J76BrNOp2Z318Ji-mifGnuWR9mOBdDebBizCnTY8qdJf6ReJ58vU9meMMok3Ee2nhSR6ISeO9G1N_wjJ=U4-IrZGdE-mL2IWSe2zvvQ_small.txt
# Скопировано: nBkSUhL2hFglnci2J76BrNOp2Z318Ji-mifGnuWR9mOBdDebBizCnTY8qdJf6ReJ58vU9meMMok3Ee2nhSR6ISeO9G1N_wjJ=U4-IrZGdE-mL2IWSe2zvvQ_transform.txt -> nBkSUhL2hFglnci2J76BrNOp2Z318Ji-mifGnuWR9mOBdDebBizCnTY8qdJf6ReJ58vU9meMMok3Ee2nhSR6ISeO9G1N_wjJ=U4-IrZGdE-mL2IWSe2zvvQ_transform_small.txt
# Скопировано: nebo-oblaka-ptitsa-chaika-polet.txt -> nebo-oblaka-ptitsa-chaika-polet_small.txt
# Скопировано: nebo-oblaka-ptitsa-chaika-polet_transform.txt -> nebo-oblaka-ptitsa-chaika-polet_transform_small.txt
# Скопировано: nebo-oblaka-solnce-ptica.txt -> nebo-oblaka-solnce-ptica_small.txt
# Скопировано: nebo-oblaka-solnce-ptica_transform.txt -> nebo-oblaka-solnce-ptica_transform_small.txt
# Скопировано: OIP (1).txt -> OIP (1)_small.txt
# Скопировано: OIP (1)_1.txt -> OIP (1)_1_small.txt
# Скопировано: OIP (10).txt -> OIP (10)_small.txt
# Скопировано: OIP (11).txt -> OIP (11)_small.txt
# Скопировано: OIP (12).txt -> OIP (12)_small.txt
# Скопировано: OIP (13).txt -> OIP (13)_small.txt
# Скопировано: OIP (14).txt -> OIP (14)_small.txt
# Скопировано: OIP (15).txt -> OIP (15)_small.txt
# Скопировано: OIP (16).txt -> OIP (16)_small.txt
# Скопировано: OIP (17).txt -> OIP (17)_small.txt
# Скопировано: OIP (18).txt -> OIP (18)_small.txt
# Скопировано: OIP (19).txt -> OIP (19)_small.txt
# Скопировано: OIP (2).txt -> OIP (2)_small.txt
# Скопировано: OIP (20).txt -> OIP (20)_small.txt
# Скопировано: OIP (21).txt -> OIP (21)_small.txt
# Скопировано: OIP (22).txt -> OIP (22)_small.txt
# Скопировано: OIP (23).txt -> OIP (23)_small.txt
# Скопировано: OIP (24).txt -> OIP (24)_small.txt
# Скопировано: OIP (25).txt -> OIP (25)_small.txt
# Скопировано: OIP (26).txt -> OIP (26)_small.txt
# Скопировано: OIP (27).txt -> OIP (27)_small.txt
# Скопировано: OIP (28).txt -> OIP (28)_small.txt
# Скопировано: OIP (29).txt -> OIP (29)_small.txt
# Скопировано: OIP (3).txt -> OIP (3)_small.txt
# Скопировано: OIP (30).txt -> OIP (30)_small.txt
# Скопировано: OIP (31).txt -> OIP (31)_small.txt
# Скопировано: OIP (4).txt -> OIP (4)_small.txt
# Скопировано: OIP (5).txt -> OIP (5)_small.txt
# Скопировано: OIP (6).txt -> OIP (6)_small.txt
# Скопировано: OIP (7).txt -> OIP (7)_small.txt
# Скопировано: OIP (8).txt -> OIP (8)_small.txt
# Скопировано: OIP.txt -> OIP_small.txt
# Скопировано: OIP_1.txt -> OIP_1_small.txt
# Скопировано: original.txt -> original_small.txt
# Скопировано: other-fares.txt -> other-fares_small.txt
# Скопировано: other-fares_transform.txt -> other-fares_transform_small.txt
# Скопировано: P1130151 copy.txt -> P1130151 copy_small.txt
# Скопировано: P1130151 copy_transform.txt -> P1130151 copy_transform_small.txt
# Скопировано: Photodr-5.txt -> Photodr-5_small.txt
# Скопировано: photodune-785697-colorful-balloon-m.txt -> photodune-785697-colorful-balloon-m_small.txt
# Скопировано: plane-airplane-take-off-landing-sunset-flying-fly-twilight.txt -> plane-airplane-take-off-landing-sunset-flying-fly-twilight_small.txt
# Скопировано: plane-airplane-take-off-landing-sunset-flying-fly-twilight_transform.txt -> plane-airplane-take-off-landing-sunset-flying-fly-twilight_transform_small.txt
# Скопировано: poledwiczki-z-indyka-w-sosie-pieczarkowym-przepis.txt -> poledwiczki-z-indyka-w-sosie-pieczarkowym-przepis_small.txt
# Скопировано: polet-na-vozdushnom-share-v-sankt-peterburge-min.txt -> polet-na-vozdushnom-share-v-sankt-peterburge-min_small.txt
# Скопировано: polet-nad-lesom-vechernij-poceluj-solnca.txt -> polet-nad-lesom-vechernij-poceluj-solnca_small.txt
# Скопировано: polet-nad-lesom-vechernij-poceluj-solnca_transform.txt -> polet-nad-lesom-vechernij-poceluj-solnca_transform_small.txt
# Скопировано: Pomarine_Jaeger_0063_61406.txt -> Pomarine_Jaeger_0063_61406_small.txt
# Скопировано: Pomarine_Jaeger_0063_61406_transform.txt -> Pomarine_Jaeger_0063_61406_transform_small.txt
# Скопировано: PWxfIFEqBIQ.txt -> PWxfIFEqBIQ_small.txt
# Скопировано: PWxfIFEqBIQ_transform.txt -> PWxfIFEqBIQ_transform_small.txt
# Скопировано: qtc3dTMn-1280.txt -> qtc3dTMn-1280_small.txt
# Скопировано: quadcopter-against-blue-sky_463270-5646.txt -> quadcopter-against-blue-sky_463270-5646_small.txt
# Скопировано: quadcopter-against-blue-sky_463270-5646_transform.txt -> quadcopter-against-blue-sky_463270-5646_transform_small.txt
# Скопировано: quadcopter-drone-with-camera-against-blue-sky_109285-1364.txt -> quadcopter-drone-with-camera-against-blue-sky_109285-1364_small.txt
# Скопировано: quadcopter-drone-with-camera-against-blue-sky_109285-1364_transform.txt -> quadcopter-drone-with-camera-against-blue-sky_109285-1364_transform_small.txt
# Скопировано: quadcopter-drone-with-camera-against-blue-sky_109285-1366.txt -> quadcopter-drone-with-camera-against-blue-sky_109285-1366_small.txt
# Скопировано: quadcopter-drone-with-camera-against-blue-sky_109285-1366_transform.txt -> quadcopter-drone-with-camera-against-blue-sky_109285-1366_transform_small.txt
# Скопировано: quadcopter-drone-with-camera-against-blue-sky_109285-1690.txt -> quadcopter-drone-with-camera-against-blue-sky_109285-1690_small.txt
# Скопировано: quadcopter-drone-with-camera-against-blue-sky_109285-1690_transform.txt -> quadcopter-drone-with-camera-against-blue-sky_109285-1690_transform_small.txt
# Скопировано: quadcopter-is-flight-aerial-videography_73741-1860 (1).txt -> quadcopter-is-flight-aerial-videography_73741-1860 (1)_small.txt
# Скопировано: quadcopter-is-flight-aerial-videography_73741-1860 (1)_transform.txt -> quadcopter-is-flight-aerial-videography_73741-1860 (1)_transform_small.txt
# Скопировано: quadcopter-is-flight-aerial-videography_73741-1860.txt -> quadcopter-is-flight-aerial-videography_73741-1860_small.txt
# Скопировано: quadcopter-mavic-flies-sky_73152-2526.txt -> quadcopter-mavic-flies-sky_73152-2526_small.txt
# Скопировано: quadcopter-mavic-flies-sky_73152-2526_transform.txt -> quadcopter-mavic-flies-sky_73152-2526_transform_small.txt
# Скопировано: quadrocopter-flight_543889-656.txt -> quadrocopter-flight_543889-656_small.txt
# Скопировано: quadrocopter-flight_543889-656_transform.txt -> quadrocopter-flight_543889-656_transform_small.txt
# Скопировано: quadrocopter-new-tool-aerial-photo-video_3579-808.txt -> quadrocopter-new-tool-aerial-photo-video_3579-808_small.txt
# Скопировано: quadrocopter-new-tool-aerial-photo-video_3579-808_transform.txt -> quadrocopter-new-tool-aerial-photo-video_3579-808_transform_small.txt
# Скопировано: que-14246581159.txt -> que-14246581159_small.txt
# Скопировано: que-14246581159_transform.txt -> que-14246581159_transform_small.txt
# Скопировано: qwss.txt -> qwss_small.txt
# Скопировано: R (1).txt -> R (1)_small.txt
# Скопировано: R (1)_1.txt -> R (1)_1_small.txt
# Скопировано: R (2).txt -> R (2)_small.txt
# Скопировано: R (3).txt -> R (3)_small.txt
# Скопировано: R (4).txt -> R (4)_small.txt
# Скопировано: R (5).txt -> R (5)_small.txt
# Скопировано: R.txt -> R_small.txt
# Скопировано: RarnApPwqMs.txt -> RarnApPwqMs_small.txt
# Скопировано: Recuperacion-del-IVA-de-los-gastos-de-viaje-internacionales-I-800x400-1.txt -> Recuperacion-del-IVA-de-los-gastos-de-viaje-internacionales-I-800x400-1_small.txt
# Скопировано: Recuperacion-del-IVA-de-los-gastos-de-viaje-internacionales-I-800x400-1_transform.txt -> Recuperacion-del-IVA-de-los-gastos-de-viaje-internacionales-I-800x400-1_transform_small.txt
# Скопировано: regnum_picture_16909935471459_big.txt -> regnum_picture_16909935471459_big_small.txt
# Скопировано: regnum_picture_16909935471459_big_transform.txt -> regnum_picture_16909935471459_big_transform_small.txt
# Скопировано: R_transform.txt -> R_transform_small.txt
# Скопировано: Sardinien_14 _020.txt -> Sardinien_14 _020_small.txt
# Скопировано: Sardinien_14 _020_transform.txt -> Sardinien_14 _020_transform_small.txt
# Скопировано: scale_1200 (1).txt -> scale_1200 (1)_small.txt
# Скопировано: scale_1200 (2).txt -> scale_1200 (2)_small.txt
# Скопировано: scale_1200 (3).txt -> scale_1200 (3)_small.txt
# Скопировано: scale_1200.txt -> scale_1200_small.txt
# Скопировано: sea-horizon-bird-wing-cloud-sky-sunset-seabird-seagull-vehicle-gull-flight-charadriiformes-spiekeroog-atmosphere-of-earth-849300.txt -> sea-horizon-bird-wing-cloud-sky-sunset-seabird-seagull-vehicle-gull-flight-charadriiformes-spiekeroog-atmosphere-of-earth-849300_small.txt
# Скопировано: sea-horizon-bird-wing-cloud-sky-sunset-seabird-seagull-vehicle-gull-flight-charadriiformes-spiekeroog-atmosphere-of-earth-849300_transform.txt -> sea-horizon-bird-wing-cloud-sky-sunset-seabird-seagull-vehicle-gull-flight-charadriiformes-spiekeroog-atmosphere-of-earth-849300_transform_small.txt
# Скопировано: shortlist01.txt -> shortlist01_small.txt
# Скопировано: shortlist01_transform.txt -> shortlist01_transform_small.txt
# Скопировано: snimok-ekrana-2023-10-02-v-11.16.24.txt -> snimok-ekrana-2023-10-02-v-11.16.24_small.txt
# Скопировано: snimok-ekrana-2023-10-02-v-11.16.24_transform.txt -> snimok-ekrana-2023-10-02-v-11.16.24_transform_small.txt
# Скопировано: Sooty_Albatross_0032_1149.txt -> Sooty_Albatross_0032_1149_small.txt
# Скопировано: Sooty_Albatross_0032_1149_transform.txt -> Sooty_Albatross_0032_1149_transform_small.txt
# Скопировано: sVVgiUjgnM429849.txt -> sVVgiUjgnM429849_small.txt
# Скопировано: sVVgiUjgnM429849_transform.txt -> sVVgiUjgnM429849_transform_small.txt
# Скопировано: tA6sJSUHyK_1600.txt -> tA6sJSUHyK_1600_small.txt
# Скопировано: tA6sJSUHyK_1600_transform.txt -> tA6sJSUHyK_1600_transform_small.txt
# Скопировано: tmb_312514_972810.txt -> tmb_312514_972810_small.txt
# Скопировано: tPFfPvmcbpk.txt -> tPFfPvmcbpk_small.txt
# Скопировано: tPFfPvmcbpk_transform.txt -> tPFfPvmcbpk_transform_small.txt
# Скопировано: TT-00006609_1-600x315.txt -> TT-00006609_1-600x315_small.txt
# Скопировано: TWhDuZm-rgY.txt -> TWhDuZm-rgY_small.txt
# Скопировано: TWhDuZm-rgY_transform.txt -> TWhDuZm-rgY_transform_small.txt
# Скопировано: TxGj7315109903208689_b.txt -> TxGj7315109903208689_b_small.txt
# Скопировано: united-states-edmond-ballon-sky.txt -> united-states-edmond-ballon-sky_small.txt
# Скопировано: uO--trMMufsfsL2zMHG1TdqMDeVjsHsNfYBfWOiS8hzx7uM2y6c1uQ4JTvX_vRqGrlSkWFBgKX5hr4_g05SmiVMI.txt -> uO--trMMufsfsL2zMHG1TdqMDeVjsHsNfYBfWOiS8hzx7uM2y6c1uQ4JTvX_vRqGrlSkWFBgKX5hr4_g05SmiVMI_small.txt
# Скопировано: vozdushnyj_shar_nebo_minimalizm_153158_2560x1600.txt -> vozdushnyj_shar_nebo_minimalizm_153158_2560x1600_small.txt
# Скопировано: vozdushnyj_shar_polet_nebo_164258_2560x1600.txt -> vozdushnyj_shar_polet_nebo_164258_2560x1600_small.txt
# Скопировано: w720h405fill.txt -> w720h405fill_small.txt
# Скопировано: w720h405fill_1.txt -> w720h405fill_1_small.txt
# Скопировано: WAXuOS15Q9A.txt -> WAXuOS15Q9A_small.txt
# Скопировано: WAXuOS15Q9A_transform.txt -> WAXuOS15Q9A_transform_small.txt
# Скопировано: w_9968db4c.txt -> w_9968db4c_small.txt
# Скопировано: w_9968db4c_transform.txt -> w_9968db4c_transform_small.txt
# Скопировано: x_5954d450.txt -> x_5954d450_small.txt
# Скопировано: x_5954d450_transform.txt -> x_5954d450_transform_small.txt
# Скопировано: yxDPyfqCzUg.txt -> yxDPyfqCzUg_small.txt
# Скопировано: yxDPyfqCzUg_transform.txt -> yxDPyfqCzUg_transform_small.txt
# Скопировано: zOsiIV3wlrw.txt -> zOsiIV3wlrw_small.txt
# Скопировано: zOsiIV3wlrw_transform.txt -> zOsiIV3wlrw_transform_small.txt
# Скопировано: ZXiLikEBdhQ.txt -> ZXiLikEBdhQ_small.txt
# Скопировано: `.txt -> `_small.txt
# Скопировано: микросельхозперепись.txt -> микросельхозперепись_small.txt
# Скопировано: микросельхозперепись_transform.txt -> микросельхозперепись_transform_small.txt

# %% [markdown]
# # Вывод фото с разметкой

# %%
import cv2
import os

def draw_bounding_boxes(image_path, labels_path, output_path):
    """
    Отображает баундинг боксы на изображении из файла разметки.

    Args:
        image_path: Путь к изображению.
        labels_path: Путь к файлу разметки (в формате YOLOv8).
        output_path: Путь к папке для сохранения обработанных изображений.
    """

    image = cv2.imread(image_path)

    if image is not None:
        # Загружаем данные из файла разметки
        with open(labels_path, 'r') as f:
            labels = f.readlines()

        # Обрабатываем каждую строку в файле разметки
        for label in labels:
            # Разделяем данные в строке
            class_id, x_center, y_center, width, height = map(float, label.strip().split())
            # Преобразуем координаты в формат OpenCV
            x_min = int((x_center - width / 2) *image.shape[1])
            y_min = int((y_center - height / 2)* image.shape[0])
            x_max = int((x_center + width / 2) *image.shape[1])
            y_max = int((y_center + height / 2) *image.shape[0])
            print("Количество пикселей по х",x_max-x_min)
            print("Количество пикселей по y",y_max-y_min)
            # Рисуем баундинг бокс
            cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

        # Сохраняем изображение с баундинг боксами
        filename = os.path.basename(image_path)
        output_filename = os.path.join(output_path, filename)
        cv2.imwrite(output_filename, image)
        print(f"Обработано: {filename}")
    else:
        print(f"Ошибка при загрузке: {image_path}")


if __name__ == '__main__':
    images_folder = 'test_perenos/images'  # Папка с изображениями
    labels_folder = 'test_perenos/labels'  # Папка с файлами разметки
    output_folder = 'output_images_perenos'  # Папка для сохранения результатов

    os.makedirs(output_folder, exist_ok=True)

    for filename in os.listdir(images_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(images_folder, filename)
            labels_path = os.path.join(labels_folder, filename.replace('.jpg', '.txt').replace('.png', '.txt'))
            draw_bounding_boxes(image_path, labels_path, output_folder)
# Out:
# Количество пикселей по х 181
# Количество пикселей по y 87
# Обработано: 08-02-2019-8-07-40.jpg
# Количество пикселей по х 163
# Количество пикселей по y 85
# Обработано: 10.jpg
# Количество пикселей по х 107
# Количество пикселей по y 127
# Обработано: 10_transform.jpg
# Количество пикселей по х 140
# Количество пикселей по y 115
# Обработано: 11.jpg
# Количество пикселей по х 85
# Количество пикселей по y 126
# Обработано: 11_transform.jpg
# Количество пикселей по х 36
# Количество пикселей по y 37
# Обработано: 12as.jpg
# Количество пикселей по х 40
# Количество пикселей по y 56
# Обработано: 12sadf.jpg
# Количество пикселей по х 31
# Количество пикселей по y 22
# Обработано: 12_1.jpg
# Количество пикселей по х 272
# Количество пикселей по y 298
# Количество пикселей по х 244
# Количество пикселей по y 266
# Количество пикселей по х 194
# Количество пикселей по y 162
# Обработано: 13.jpg
# Количество пикселей по х 30
# Количество пикселей по y 25
# Количество пикселей по х 24
# Количество пикселей по y 39
# Количество пикселей по х 32
# Количество пикселей по y 23
# Количество пикселей по х 20
# Количество пикселей по y 17
# Количество пикселей по х 23
# Количество пикселей по y 20
# Количество пикселей по х 26
# Количество пикселей по y 21
# Количество пикселей по х 24
# Количество пикселей по y 23
# Количество пикселей по х 24
# Количество пикселей по y 22
# Количество пикселей по х 21
# Количество пикселей по y 19
# Количество пикселей по х 17
# Количество пикселей по y 15
# Количество пикселей по х 20
# Количество пикселей по y 21
# Количество пикселей по х 22
# Количество пикселей по y 26
# Количество пикселей по х 27
# Количество пикселей по y 22
# Количество пикселей по х 19
# Количество пикселей по y 21
# Количество пикселей по х 19
# Количество пикселей по y 17
# Количество пикселей по х 24
# Количество пикселей по y 15
# Количество пикселей по х 22
# Количество пикселей по y 22
# Количество пикселей по х 24
# Количество пикселей по y 19
# Количество пикселей по х 20
# Количество пикселей по y 20
# Количество пикселей по х 25
# Количество пикселей по y 20
# Количество пикселей по х 20
# Количество пикселей по y 26
# Количество пикселей по х 27
# Количество пикселей по y 26
# Обработано: 13sadasd.jpg
# Количество пикселей по х 47
# Количество пикселей по y 35
# Обработано: 13_1.jpg
# Количество пикселей по х 32
# Количество пикселей по y 26
# Обработано: 13_transform.jpg
# Количество пикселей по х 24
# Количество пикселей по y 20
# Обработано: 14.jpg
# Количество пикселей по х 63
# Количество пикселей по y 52
# Обработано: 14dsagdsag.jpg
# Количество пикселей по х 22
# Количество пикселей по y 19
# Обработано: 14_transform.jpg
# Количество пикселей по х 112
# Количество пикселей по y 239
# Количество пикселей по х 43
# Количество пикселей по y 193
# Обработано: 15.jpg
# Количество пикселей по х 41
# Количество пикселей по y 31
# Обработано: 15_1.jpg
# Количество пикселей по х 25
# Количество пикселей по y 22
# Количество пикселей по х 22
# Количество пикселей по y 19
# Количество пикселей по х 19
# Количество пикселей по y 17
# Количество пикселей по х 16
# Количество пикселей по y 11
# Количество пикселей по х 19
# Количество пикселей по y 16
# Количество пикселей по х 20
# Количество пикселей по y 17
# Обработано: 16.jpg
# Количество пикселей по х 30
# Количество пикселей по y 20
# Количество пикселей по х 25
# Количество пикселей по y 18
# Количество пикселей по х 26
# Количество пикселей по y 18
# Обработано: 16_transform.jpg
# Количество пикселей по х 112
# Количество пикселей по y 82
# Обработано: 17.jpg
# Количество пикселей по х 36
# Количество пикселей по y 24
# Обработано: 18.jpg
# Количество пикселей по х 23
# Количество пикселей по y 14
# Обработано: 19.jpg
# Количество пикселей по х 29
# Количество пикселей по y 30
# Обработано: 19_transform.jpg
# Количество пикселей по х 160
# Количество пикселей по y 156
# Обработано: 20.jpg
# Количество пикселей по х 128
# Количество пикселей по y 94
# Обработано: 20_transform.jpg
# Количество пикселей по х 26
# Количество пикселей по y 21
# Количество пикселей по х 41
# Количество пикселей по y 40
# Количество пикселей по х 41
# Количество пикселей по y 30
# Количество пикселей по х 60
# Количество пикселей по y 45
# Обработано: 21.jpg
# Количество пикселей по х 65
# Количество пикселей по y 56
# Количество пикселей по х 44
# Количество пикселей по y 37
# Обработано: 21_transform.jpg
# Количество пикселей по х 66
# Количество пикселей по y 64
# Обработано: 22.jpg
# Количество пикселей по х 49
# Количество пикселей по y 49
# Обработано: 22_transform.jpg
# Количество пикселей по х 30
# Количество пикселей по y 26
# Обработано: 23.jpg
# Количество пикселей по х 14
# Количество пикселей по y 15
# Обработано: 23_transform.jpg
# Количество пикселей по х 61
# Количество пикселей по y 51
# Обработано: 24.jpg
# Количество пикселей по х 97
# Количество пикселей по y 69
# Обработано: 24_transform.jpg
# Количество пикселей по х 78
# Количество пикселей по y 78
# Количество пикселей по х 28
# Количество пикселей по y 20
# Обработано: 25.jpg
# Количество пикселей по х 45
# Количество пикселей по y 43
# Количество пикселей по х 19
# Количество пикселей по y 18
# Обработано: 25_transform.jpg
# Количество пикселей по х 129
# Количество пикселей по y 119
# Обработано: 26.jpg
# Количество пикселей по х 116
# Количество пикселей по y 79
# Обработано: 26_transform.jpg
# Количество пикселей по х 73
# Количество пикселей по y 42
# Обработано: 27.jpg
# Количество пикселей по х 37
# Количество пикселей по y 33
# Обработано: 27_transform.jpg
# Количество пикселей по х 104
# Количество пикселей по y 69
# Обработано: 28.jpg
# Количество пикселей по х 140
# Количество пикселей по y 91
# Обработано: 28_transform.jpg
# Количество пикселей по х 45
# Количество пикселей по y 34
# Обработано: 29.jpg
# Количество пикселей по х 44
# Количество пикселей по y 32
# Обработано: 29_transform.jpg
# Количество пикселей по х 53
# Количество пикселей по y 37
# Обработано: 30.jpg
# Количество пикселей по х 43
# Количество пикселей по y 25
# Обработано: 30_transform.jpg
# Количество пикселей по х 55
# Количество пикселей по y 27
# Обработано: 31.jpg
# Количество пикселей по х 51
# Количество пикселей по y 30
# Обработано: 32.jpg
# Количество пикселей по х 46
# Количество пикселей по y 27
# Обработано: 32_transform.jpg
# Количество пикселей по х 98
# Количество пикселей по y 62
# Обработано: 33.jpg
# Количество пикселей по х 116
# Количество пикселей по y 79
# Обработано: 33_transform.jpg
# Количество пикселей по х 48
# Количество пикселей по y 43
# Количество пикселей по х 19
# Количество пикселей по y 16
# Обработано: 34.jpg
# Количество пикселей по х 61
# Количество пикселей по y 50
# Количество пикселей по х 22
# Количество пикселей по y 15
# Обработано: 34_transform.jpg
# Количество пикселей по х 83
# Количество пикселей по y 41
# Обработано: 35.jpg
# Количество пикселей по х 62
# Количество пикселей по y 45
# Обработано: 35_transform.jpg
# Количество пикселей по х 91
# Количество пикселей по y 71
# Обработано: 36.jpg
# Количество пикселей по х 73
# Количество пикселей по y 59
# Обработано: 38.jpg
# Количество пикселей по х 71
# Количество пикселей по y 62
# Обработано: 39.jpg
# Количество пикселей по х 64
# Количество пикселей по y 57
# Обработано: 40.jpg
# Количество пикселей по х 84
# Количество пикселей по y 56
# Обработано: 40_transform.jpg
# Количество пикселей по х 88
# Количество пикселей по y 66
# Обработано: 41.jpg
# Количество пикселей по х 65
# Количество пикселей по y 56
# Обработано: 41_transform.jpg
# Количество пикселей по х 96
# Количество пикселей по y 92
# Обработано: 42.jpg
# Количество пикселей по х 91
# Количество пикселей по y 71
# Обработано: 43.jpg
# Количество пикселей по х 61
# Количество пикселей по y 64
# Обработано: 43_transform.jpg
# Количество пикселей по х 96
# Количество пикселей по y 116
# Обработано: 44.jpg
# Количество пикселей по х 95
# Количество пикселей по y 120
# Обработано: 44_transform.jpg
# Количество пикселей по х 136
# Количество пикселей по y 110
# Обработано: 45.jpg
# Количество пикселей по х 100
# Количество пикселей по y 78
# Обработано: 45_transform.jpg
# Количество пикселей по х 142
# Количество пикселей по y 105
# Обработано: 46.jpg
# Количество пикселей по х 74
# Количество пикселей по y 65
# Обработано: 46_transform.jpg
# Количество пикселей по х 105
# Количество пикселей по y 76
# Обработано: 47.jpg
# Количество пикселей по х 135
# Количество пикселей по y 62
# Обработано: 47_transform.jpg
# Количество пикселей по х 87
# Количество пикселей по y 61
# Обработано: 48.jpg
# Количество пикселей по х 42
# Количество пикселей по y 65
# Обработано: 48_transform.jpg
# Количество пикселей по х 124
# Количество пикселей по y 69
# Обработано: 49.jpg
# Количество пикселей по х 84
# Количество пикселей по y 56
# Обработано: 49_transform.jpg
# Обработано: 4b0034a9642450dcbafe55d798e9afa6.jpg
# Количество пикселей по х 57
# Количество пикселей по y 36
# Обработано: 4b7534204_1289410.jpg
# Количество пикселей по х 519
# Количество пикселей по y 370
# Обработано: 4edcd99b87ec7f78b73ea59ad1bce600.jpg
# Количество пикселей по х 63
# Количество пикселей по y 83
# Обработано: 4_transform_1.jpg
# Количество пикселей по х 403
# Количество пикселей по y 352
# Обработано: 5.jpg
# Количество пикселей по х 99
# Количество пикселей по y 89
# Количество пикселей по х 149
# Количество пикселей по y 128
# Обработано: 50.jpg
# Количество пикселей по х 125
# Количество пикселей по y 104
# Обработано: 50_transform.jpg
# Количество пикселей по х 34
# Количество пикселей по y 24
# Обработано: 51.jpg
# Количество пикселей по х 40
# Количество пикселей по y 34
# Обработано: 51_transform.jpg
# Количество пикселей по х 163
# Количество пикселей по y 122
# Обработано: 52.jpg
# Количество пикселей по х 179
# Количество пикселей по y 159
# Обработано: 52_transform.jpg
# Количество пикселей по х 33
# Количество пикселей по y 27
# Количество пикселей по х 42
# Количество пикселей по y 24
# Обработано: 53.jpg
# Количество пикселей по х 20
# Количество пикселей по y 24
# Обработано: 53_transform.jpg
# Количество пикселей по х 229
# Количество пикселей по y 154
# Обработано: 5_1.jpg
# Количество пикселей по х 171
# Количество пикселей по y 140
# Обработано: 5_transform.jpg
# Количество пикселей по х 46
# Количество пикселей по y 46
# Обработано: 6.jpg
# Количество пикселей по х 222
# Количество пикселей по y 142
# Обработано: 7.jpg
# Количество пикселей по х 58
# Количество пикселей по y 91
# Обработано: 7f02b39d408d25536f77023ef10e29c5.jpg
# Количество пикселей по х 144
# Количество пикселей по y 56
# Обработано: 7_transform.jpg
# Количество пикселей по х 280
# Количество пикселей по y 137
# Обработано: 8.jpg
# Количество пикселей по х 91
# Количество пикселей по y 53
# Обработано: 8e7b95947322bcaf47299e69984d0220.jpg
# Количество пикселей по х 139
# Количество пикселей по y 135
# Обработано: 8_transform.jpg
# Количество пикселей по х 120
# Количество пикселей по y 79
# Обработано: 9.jpg
# Количество пикселей по х 92
# Количество пикселей по y 101
# Обработано: 9b3a5b54ef2284b60dceef0d2ac6a8dc0c59f473_1280_720_c.jpg
# Количество пикселей по х 108
# Количество пикселей по y 75
# Количество пикселей по х 105
# Количество пикселей по y 71
# Обработано: 9fe9fc06d3c651c9e64637caf79104da.jpg
# Количество пикселей по х 75
# Количество пикселей по y 67
# Обработано: 9_transform.jpg

# %% [markdown]
# # Попытка в перенос меток

# %%
import os
import cv2
import albumentations as A
from albumentations.pytorch import ToTensorV2
import numpy as np
import torch

def transform_image_and_labels(image_path, labels_path, output_image_folder, output_labels_folder, transform_base):
    """
    Применяет преобразования к изображению и корректирует разметку.

    Args:
        image_path: Путь к изображению.
        labels_path: Путь к файлу разметки (в формате YOLOv8).
        output_image_folder: Папка для сохранения преобразованных изображений.
        output_labels_folder: Папка для сохранения преобразованных файлов разметки.
        transform_base: Базовый объект преобразования (Albumentations) без обрезки.
    """
    image = cv2.imread(image_path)

    if image is not None:
        height, width, _ = image.shape

        # Загружаем данные из файла разметки
        with open(labels_path, 'r') as f:
            labels = f.readlines()

        # Преобразуем метки в нужный формат
        annotations = []
        for label in labels:
            class_id, x_center, y_center, box_width, box_height = map(float, label.strip().split())
            # Переходим к формату (x_min, y_min, x_max, y_max)
            x_min = (x_center - box_width / 2) * width
            y_min = (y_center - box_height / 2) * height
            x_max = (x_center + box_width / 2) * width
            y_max = (y_center + box_height / 2) * height

            # Убедимся, что координаты находятся в пределах изображения
            x_min = max(min(x_min, width - 1), 0)
            y_min = max(min(y_min, height - 1), 0)
            x_max = max(min(x_max, width - 1), 0)
            y_max = max(min(y_max, height - 1), 0)

            annotations.append([x_min, y_min, x_max, y_max, int(class_id)])

        # Добавляем обрезку динамически, если размеры изображения позволяют
        transform = transform_base

        if width >= 640 and height >= 640:
            transform = A.Compose([
                A.RandomCrop(width=640, height=640, p=0.5),  # Случайное кадрирование
                *transform_base.transforms
            ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['class_labels'], min_visibility=0.2))

        # Применяем преобразования к изображению и аннотациям
        transformed = transform(image=image, bboxes=annotations, class_labels=[ann[4] for ann in annotations])
        transformed_image = transformed['image']
        transformed_bboxes = transformed['bboxes']

        # Преобразуем тензор обратно в numpy.ndarray
        if isinstance(transformed_image, torch.Tensor):
            transformed_image = transformed_image.permute(1, 2, 0).cpu().numpy()
            # Переводим значения пикселей из [0, 1] в [0, 255] для сохранения в формате изображения
            transformed_image = (transformed_image * 255).astype(np.uint8)

        # Преобразуем метки обратно в формат YOLO
        new_labels = []
        for bbox in transformed_bboxes:
            x_min, y_min, x_max, y_max, class_id = bbox

            # Пересчитываем в центр и нормализуем
            x_center = ((x_min + x_max) / 2) / width
            y_center = ((y_min + y_max) / 2) / height
            box_width = (x_max - x_min) / width
            box_height = (y_max - y_min) / height

            # Убедимся, что все координаты находятся в пределах [0, 1]
            x_center = min(max(x_center, 0), 1)
            y_center = min(max(y_center, 0), 1)
            box_width = min(max(box_width, 0), 1)
            box_height = min(max(box_height, 0), 1)

            # Если размеры бокса или его центр выходят за границы, пропустим эту аннотацию
            if x_center <= 0 or x_center >= 1 or y_center <= 0 or y_center >= 1 or box_width <= 0 or box_height <= 0:
                continue

            new_labels.append(f"{class_id} {x_center} {y_center} {box_width} {box_height}\n")

        # Сохраняем преобразованное изображение и обновленную разметку
        filename = os.path.basename(image_path)
        output_image_path = os.path.join(output_image_folder, filename)
        output_labels_path = os.path.join(output_labels_folder, filename.replace('.jpg', '.txt').replace('.png', '.txt'))
        cv2.imwrite(output_image_path, transformed_image)
        with open(output_labels_path, 'w') as f:
            f.writelines(new_labels)
        print(f"Обработано: {filename}")
    else:
        print(f"Ошибка при загрузке: {image_path}")

if __name__ == '__main__':
    images_folder = 'images'
    labels_folder = 'labels'
    output_image_folder = 'test_perenos/images'
    output_labels_folder = 'test_perenos/labels'

    os.makedirs(output_image_folder, exist_ok=True)
    os.makedirs(output_labels_folder, exist_ok=True)

    # Базовый объект преобразования без обрезки
    transform_base = A.Compose([
        A.HorizontalFlip(p=0.5),  # Горизонтальное отражение с вероятностью 50%
        A.RandomBrightnessContrast(p=0.2),  # Случайное изменение яркости и контрастности
        A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.1, rotate_limit=15, p=0.5),  # Перемещение, масштабирование и поворот
        ToTensorV2()  # Преобразование изображения в тензор PyTorch
    ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['class_labels'], min_visibility=0.2))

    for filename in os.listdir(images_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(images_folder, filename)
            labels_path = os.path.join(labels_folder, filename.replace('.jpg', '.txt').replace('.png', '.txt'))
            transform_image_and_labels(image_path, labels_path, output_image_folder, output_labels_folder, transform_base)
# Out:
# Обработано: 08-02-2019-8-07-40.jpg
# Обработано: 10.jpg
# Обработано: 10_transform.jpg
# Обработано: 11.jpg
# Обработано: 11_transform.jpg
# Обработано: 12as.jpg
# Обработано: 12sadf.jpg
# Обработано: 12_1.jpg
# Обработано: 13.jpg
# Обработано: 13sadasd.jpg
